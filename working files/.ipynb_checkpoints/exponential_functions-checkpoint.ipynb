# %% [markdown]
# # Exponential Functions

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

values = [-2, -1, 0, 1, 2]

for x in values:
    print(f"e^{x} = {math.exp(x)}")
# Out:
# e^-2 = 0.1353352832366127
# e^-1 = 0.36787944117144233
# e^0 = 1.0
# e^1 = 2.718281828459045
# e^2 = 7.38905609893065

# %% [markdown]
# > linspace generates numbers with a specific step size. linspace() allows you to specify the total number of points you want in the array, and NumPy will calculate the spacing between the numbers automatically. **

# %%
# # Generate 100 numbers between -2 and 2
x = np.linspace(-2, 2, 50)
print("linspace", x)
y = np.exp(x)

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("e^x")
plt.title("Graph of e^x")
plt.show()
# Out:
# linspace [-2.         -1.91836735 -1.83673469 -1.75510204 -1.67346939 -1.59183673
#  -1.51020408 -1.42857143 -1.34693878 -1.26530612 -1.18367347 -1.10204082
#  -1.02040816 -0.93877551 -0.85714286 -0.7755102  -0.69387755 -0.6122449
#  -0.53061224 -0.44897959 -0.36734694 -0.28571429 -0.20408163 -0.12244898
#  -0.04081633  0.04081633  0.12244898  0.20408163  0.28571429  0.36734694
#   0.44897959  0.53061224  0.6122449   0.69387755  0.7755102   0.85714286
#   0.93877551  1.02040816  1.10204082  1.18367347  1.26530612  1.34693878
#   1.42857143  1.51020408  1.59183673  1.67346939  1.75510204  1.83673469
#   1.91836735  2.        ]

# %% [markdown]
# ### Growth & decay

# %% [markdown]
# | Expression | Meaning            |
# | ---------- | ------------------ |
# | ( e^x )    | Exponential growth |
# | ( e^{-x} ) | Exponential decay  |

# %% [markdown]
# ### Sigmoid Function (Binary Classification)

# %% [markdown]
# | x  | ( e^{-x} ) | Sigmoid |
# | -- | ---------- | ------- |
# | -∞ | ∞          | 0       |
# | 0  | 1          | 0.5     |
# | +∞ | 0          | 1       |
#
# ✔️ Output is always between 0 and 1

# %%
x = np.linspace(-10, 10, 100)
print("linspace", x)
y = 1 / (1 + np.exp(-x))

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("Sigmoid(x)")
plt.title("Sigmoid Function")
plt.show()
# Out:
# linspace [-10.          -9.7979798   -9.5959596   -9.39393939  -9.19191919
#   -8.98989899  -8.78787879  -8.58585859  -8.38383838  -8.18181818
#   -7.97979798  -7.77777778  -7.57575758  -7.37373737  -7.17171717
#   -6.96969697  -6.76767677  -6.56565657  -6.36363636  -6.16161616
#   -5.95959596  -5.75757576  -5.55555556  -5.35353535  -5.15151515
#   -4.94949495  -4.74747475  -4.54545455  -4.34343434  -4.14141414
#   -3.93939394  -3.73737374  -3.53535354  -3.33333333  -3.13131313
#   -2.92929293  -2.72727273  -2.52525253  -2.32323232  -2.12121212
#   -1.91919192  -1.71717172  -1.51515152  -1.31313131  -1.11111111
#   -0.90909091  -0.70707071  -0.50505051  -0.3030303   -0.1010101
#    0.1010101    0.3030303    0.50505051   0.70707071   0.90909091
#    1.11111111   1.31313131   1.51515152   1.71717172   1.91919192
#    2.12121212   2.32323232   2.52525253   2.72727273   2.92929293
#    3.13131313   3.33333333   3.53535354   3.73737374   3.93939394
# ...

# %% [markdown]
# ### Softmax Function (Multi-class classification)

# %% [markdown]
# ✔️ Converts raw scores into probabilities
# ✔️ All outputs add up to 1

# %%
import numpy as np

scores = np.array([2.0, 1.0, 0.0])
exp_scores = np.exp(scores)
softmax = exp_scores / np.sum(exp_scores)

print(softmax)
# Out:
# [0.66524096 0.24472847 0.09003057]
