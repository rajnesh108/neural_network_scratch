# %% [markdown]
# ## Synapses and Weights in Spiking Neural Networks (SNNs)

# %% [markdown]
# ### 🧠 What is a Synapse?
#
# A synapse is the connection between two neurons.
#
# Neuron A  ────(synapse)────>  Neuron B
#
# Neuron A = pre-synaptic neuron
#
# Neuron B = post-synaptic neuron
#
# When neuron A fires a spike, the signal passes through the synapse and affects neuron B.
#
# This models the biological Synapse in the brain.

# %% [markdown]
# ## ⚡ What is Synaptic Weight?

# %% [markdown]
# Each synapse has a weight (strength).
#
# Weight Value	Effect
# Large weight	Strong influence
# Small weight	Weak influence
# Negative weight	Inhibition
#
# Example:
#
# Neuron A spike → weight = 0.8 → Neuron B voltage increases
# Neuron A spike → weight = -0.5 → Neuron B voltage decreases
#
# So weights control how strongly neurons influence each other
#
# Vpost​=Vpost​+w

# %%
from brian2 import *

start_scope()

# neuron equation
tau = 10*ms

eqs = '''
dv/dt = (1 - v)/tau : 1
'''

# create neurons
G = NeuronGroup(2, eqs, threshold='v>0.8', reset='v=0', method='exact')

# create synapse
S = Synapses(G, G, on_pre='v_post += 0.3')
S.connect(i=0, j=1)

# monitors
M = StateMonitor(G, 'v', record=True)
spike_mon = SpikeMonitor(G)

run(100*ms)

plot(M.t/ms, M.v[0], label="Neuron 0")
plot(M.t/ms, M.v[1], label="Neuron 1")
legend()
show()
# Out:
# ---------------------------------------------------------------------------
# DimensionMismatchError                    Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\brian2\equations\equations.py:1175, in Equations.check_units(self, group, run_namespace)
#    1174 try:
# -> 1175     check_dimensions(
#    1176         str(eq.expr), self.dimensions[var] / second.dim, all_variables
#    1177     )
#    1178 except DimensionMismatchError as ex:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\brian2\equations\unitcheck.py:46, in check_dimensions(expression, dimensions, variables)
#      43 err_msg = (
#      44     f"Expression '{expression.strip()}' does not have the expected unit {expected}"
#      45 )
# ---> 46 fail_for_dimension_mismatch(expr_dims, dimensions, err_msg)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\brian2\units\fundamentalunits.py:265, in fail_for_dimension_mismatch(obj1, obj2, error_message, **error_quantities)
#     264 if obj2 is None or isinstance(obj2, (Dimension, Unit)):
# --> 265     raise DimensionMismatchError(error_message, dim1)
#     266 else:
#
# DimensionMismatchError: Expression '(1 - v)/10*ms' does not have the expected unit hertz (unit is s).
#
# The above exception was the direct cause of the following exception:
#
# DimensionMismatchError                    Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\brian2\core\network.py:1006, in Network.before_run(self, run_namespace)
#    1005 try:
# -> 1006     obj.before_run(run_namespace)
#    1007 except Exception as ex:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\brian2\groups\neurongroup.py:869, in NeuronGroup.before_run(self, run_namespace)
#     867 def before_run(self, run_namespace=None):
#     868     # Check units
# --> 869     self.equations.check_units(self, run_namespace=run_namespace)
#     870     # Check that subexpressions that refer to stateful functions are labeled
#     871     # as "constant over dt"
#
# File ~\AppData\Roaming\Python\Python314\site-packages\brian2\equations\equations.py:1179, in Equations.check_units(self, group, run_namespace)
#    1178     except DimensionMismatchError as ex:
# -> 1179         raise DimensionMismatchError(
#    1180             "Inconsistent units in "
#    1181             "differential equation "
#    1182             f"defining variable '{eq.varname}':"
#    1183             f"\n{ex.desc}",
#    1184             *ex.dims,
#    1185         ) from ex
#    1186 elif eq.type == SUBEXPRESSION:
#
# DimensionMismatchError: Inconsistent units in differential equation defining variable 'v':
# Expression '(1 - v)/10*ms' does not have the expected unit hertz (unit is s).
#
# The above exception was the direct cause of the following exception:
#
# BrianObjectException                      Traceback (most recent call last)
# Cell In[1], line 21
#      18 M = StateMonitor(G, 'v', record=True)
#      19 spike_mon = SpikeMonitor(G)
# ---> 21 run(100*ms)
#      23 plot(M.t/ms, M.v[0], label="Neuron 0")
#      24 plot(M.t/ms, M.v[1], label="Neuron 1")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\brian2\units\fundamentalunits.py:2661, in check_units.<locals>.do_check_units.<locals>.new_f(*args, **kwds)
#    2651             error_message = (
#    2652                 f"Function '{f.__name__}' "
#    2653                 "expected a quantity with unit "
#    2654                 f"{unit} for argument '{k}' but got "
#    2655                 f"'{value}'"
#    2656             )
#    2657             raise DimensionMismatchError(
#    2658                 error_message, get_dimensions(newkeyset[k])
#    2659             )
# -> 2661 result = f(*args, **kwds)
#    2662 if "result" in au:
#    2663     if isinstance(au["result"], Callable) and au["result"] not in (
#    2664         bool,
#    2665         np.bool_,
#    2666     ):
#
# File ~\AppData\Roaming\Python\Python314\site-packages\brian2\core\magic.py:407, in run(duration, report, report_period, namespace, profile, level)
#     334 @check_units(duration=second, report_period=second)
#     335 def run(
#     336     duration,
#    (...)    341     level=0,
#     342 ):
#     343     """
#     344     run(duration, report=None, report_period=10*second, namespace=None, level=0)
#     345
#    (...)    405         intended use. See `MagicNetwork` for more details.
#     406     """
# --> 407     return magic_network.run(
#     408         duration,
#     409         report=report,
#     410         report_period=report_period,
#     411         namespace=namespace,
#     412         profile=profile,
#     413         level=2 + level,
#     414     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\brian2\core\magic.py:248, in MagicNetwork.run(self, duration, report, report_period, namespace, profile, level)
#     238 def run(
#     239     self,
#     240     duration,
#    (...)    245     level=0,
#     246 ):
#     247     self._update_magic_objects(level=level + 1)
# --> 248     Network.run(
#     249         self,
#     250         duration,
#     251         report=report,
#     252         report_period=report_period,
#     253         namespace=namespace,
#     254         profile=profile,
#     255         level=level + 1,
#     256     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\brian2\core\base.py:349, in device_override.<locals>.device_override_decorator.<locals>.device_override_decorated_function(*args, **kwds)
#     347     return getattr(curdev, name)(*args, **kwds)
#     348 else:
# --> 349     return func(*args, **kwds)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\brian2\units\fundamentalunits.py:2661, in check_units.<locals>.do_check_units.<locals>.new_f(*args, **kwds)
#    2651             error_message = (
#    2652                 f"Function '{f.__name__}' "
#    2653                 "expected a quantity with unit "
#    2654                 f"{unit} for argument '{k}' but got "
#    2655                 f"'{value}'"
#    2656             )
#    2657             raise DimensionMismatchError(
#    2658                 error_message, get_dimensions(newkeyset[k])
#    2659             )
# -> 2661 result = f(*args, **kwds)
#    2662 if "result" in au:
#    2663     if isinstance(au["result"], Callable) and au["result"] not in (
#    2664         bool,
#    2665         np.bool_,
#    2666     ):
#
# File ~\AppData\Roaming\Python\Python314\site-packages\brian2\core\network.py:1143, in Network.run(self, duration, report, report_period, namespace, profile, level)
#    1140 if namespace is None:
#    1141     namespace = get_local_namespace(level=level + 3)
# -> 1143 self.before_run(namespace)
#    1145 if len(all_objects) == 0:
#    1146     return  # TODO: raise an error? warning?
#
# File ~\AppData\Roaming\Python\Python314\site-packages\brian2\core\base.py:349, in device_override.<locals>.device_override_decorator.<locals>.device_override_decorated_function(*args, **kwds)
#     347     return getattr(curdev, name)(*args, **kwds)
#     348 else:
# --> 349     return func(*args, **kwds)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\brian2\core\network.py:1008, in Network.before_run(self, run_namespace)
#    1006             obj.before_run(run_namespace)
#    1007         except Exception as ex:
# -> 1008             raise BrianObjectException(
#    1009                 "An error occurred when preparing an object.", obj
#    1010             ) from ex
#    1012 # Check that no object has been run as part of another network before
#    1013 for obj in all_objects:
#
# BrianObjectException: Error encountered with object named 'neurongroup'.
# Object was created here (most recent call only, full details in debug log):
#   File 'C:\Users\rajne\AppData\Local\Temp\ipykernel_26200\599713507.py', line 11, in <module>
#     G = NeuronGroup(2, eqs, threshold='v>0.8', reset='v=0', method='exact')
#
# An error occurred when preparing an object. (See above for original error message and traceback.)
